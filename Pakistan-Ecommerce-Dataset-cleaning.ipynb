# %% [markdown]
# <a href="https://colab.research.google.com/github/SymbolPamnani/AI_asssignment/blob/main/AIassign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data preprocessing / data cleaning on real-world dataset
# Exploratory Data Analysis

# %%
import pandas as pd
df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
df.head()
# Out:
# /tmp/ipykernel_1707/156398698.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# ...

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
#Removing unnecessary columns, if present.
df = df.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
#Handles all null values
df.isnull().sum()
# Out:
# item_id                       0
# status                        0
# created_at                    0
# sku                          15
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1               0
# sales_commission_code         4
# discount_amount               0
# payment_method                0
# Working Date                  1
# BI Status                     1
#  MV                           1
# Year                          1
# Month                         1
# Customer Since                1
# M-Y                           1
# FY                            1
# Customer ID                   1
# Unnamed: 21              175527
# Unnamed: 22              175527
# Unnamed: 23              175527
# Unnamed: 24              175527
# Unnamed: 25              175527
# dtype: int64

# %%
#Handle duplicates: if any remove them
df = df.drop_duplicates()

# %%
#Fill null values with mean or 0:
df = df.fillna(0)

# %%
import pandas as pd

sym = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
sym.head()
# Out:
# /tmp/ipykernel_1707/1559216915.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sym = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# ...

# %%
import pandas as pd

df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
# Out:
# /tmp/ipykernel_1707/2193182071.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Find Correlations
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])
correlation = numeric_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True)
plt.show()

# %%
#Find most important features for grand_total
correlation['grand_total'].sort_values(ascending=False)
# Out:
# grand_total        1.000000
# price              0.752178
# discount_amount    0.157674
# qty_ordered        0.075151
# Year               0.072743
# Customer ID        0.039630
# item_id            0.039561
# Month             -0.076033
# Unnamed: 21             NaN
# Unnamed: 22             NaN
# Unnamed: 23             NaN
# Unnamed: 24             NaN
# Unnamed: 25             NaN
# Name: grand_total, dtype: float64

# %%
#Scatter Plot of Important Features
plt.scatter(df['qty_ordered'], df['grand_total'])
plt.xlabel("Quantity Ordered")
plt.ylabel("Grand Total")
plt.show()

# %%
#Handling outliers
import numpy as np

Q1 = df['grand_total'].quantile(0.25)
Q3 = df['grand_total'].quantile(0.75)

IQR = Q3 - Q1

df = df[(df['grand_total'] >= Q1 - 1.5*IQR) & (df['grand_total'] <= Q3 + 1.5*IQR)]

# %% [markdown]
# Q:
# What is the best-selling category?
# A:
# The best-selling category is the one with the highest number of orders in the dataset. By analyzing the frequency of the category_name_1 column, we can determine which category has the most sales.
# The category with the highest count represents the most popular products among customers

# %%
df['category_name_1'].value_counts()
# Out:
# category_name_1
# Men's Fashion         30695
# Soghaat               19701
# Mobiles & Tablets     17787
# Beauty & Grooming     15862
# Women's Fashion       14339
# Superstore             8483
# Appliances             8196
# Home & Living          7025
# Health & Sports        5412
# Kids & Baby            4685
# \N                     4658
# Computing              4171
# Entertainment          2141
# Others                 2031
# School & Education     1600
# Books                   574
# Name: count, dtype: int64

# %%
df['category_name_1'].value_counts().plot(kind='bar')
plt.title("Best Selling Category")
plt.show()

# %%
#Find a correlation between payment method and order status
df['payment_method'].value_counts().plot(kind='bar')
plt.title("Payment Method Frequency")
plt.show()

# %%
df['status'].value_counts().plot(kind='bar')
plt.title("Order Status Frequency")
plt.show()

# %%
pd.crosstab(df['payment_method'], df['status'])
# Out:
# status             canceled  closed  complete  exchange  holded  \
# payment_method
# Easypay                 782       0       383         0       0
# Easypay_MA              240       0       144         0       0
# Payaxis               16360      18      5096         0       0
# c                         0       0         1         0       0
# cashatdoorstep            4       0       630         0       0
# cod                    4543     227     70419         4       6
# customercredit           23      11      1820         0       0
# easypay_voucher         146       0        52         0       0
# financesettlement         0       0         0         0       0
# internetbanking         190       4       118         0       0
# jazzvoucher            3476       2      2959         0       0
# jazzwallet             7204       1      7641         0       0
# marketingexpense          0       0        34         0       0
# ...

# %%
#Correlation Between Order Date & Category
df['created_at'] = pd.to_datetime(df['created_at'])

df.groupby(df['created_at'].dt.month)['category_name_1'].value_counts()
# Out:
# created_at  category_name_1
# 1           Men's Fashion         1898
#             Soghaat               1685
#             Women's Fashion       1053
#             Superstore            1008
#             Beauty & Grooming      808
#                                   ...
# 12          Computing              206
#             School & Education     203
#             Entertainment          131
#             Others                  83
#             Books                   52
# Name: count, Length: 144, dtype: int64

# %%
# Find any hidden patterns that are counter-intuitive for a layman
sns.boxplot(x='payment_method', y='grand_total', data=df)
plt.show()
